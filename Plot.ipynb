# %%
import numpy as np
import seaborn
# %matplotlib inline
#Все функции matplotlib API, в частности plot и close, находятся в модуле matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
def format_table(source):
    table = np.loadtxt(source)
    
    formatted_table = np.zeros((201, 201))
    for i in range(0, 201, 1):
        for j in range(0, 201, 1):
            formatted_table[200 - i][j] = table[201 * j +  i][2]
            
    return formatted_table

def pic(formatted_table, output):
    fig = plt.figure(figsize=(16,12))
    seaborn.set(font_scale=2)
    h = seaborn.heatmap(formatted_table, cmap="RdBu_r", square=True, linewidths=0.0)
    
    h.set_xticks([1, 51, 101, 151, 201])
    h.set_xticklabels(labels=[-10, -5, 0, 5, 10], fontdict={'fontsize': 30})
    h.set_yticks([1, 51, 101, 151, 201])
    h.set_yticklabels(labels=[10, 5, 0, -5, -10], fontdict={'fontsize': 30})

    h.tick_params(length=10, width=3)

    cax = plt.gcf().axes[-1]
    cax.tick_params(labelsize=20, length=10, width=3)
    cax.xaxis.label.set_size(20)

    fig.savefig(output, dpi=200)

# %%
source_list = ["../build-Custom_Omnivehicle_Control_Predict-Desktop_Qt_5_14_0_GCC_64bit-Debug/energy_0.dat",
              "../build-Custom_Omnivehicle_Control_Predict-Desktop_Qt_5_14_0_GCC_64bit-Debug/energy_turn.dat"]

output_list = ["./energy_0.png", "./energy_turn.png"]

for i in range(len(source_list)):
    pic(format_table(source_list[i]), output_list[i])

# %%
table = np.loadtxt(source_list[1])

# %%
table
# Out:
# array([[-1.00000e+01, -1.00000e+01,  3.32924e+07],
#        [-1.00000e+01, -9.90000e+00,  3.29870e+07],
#        [-1.00000e+01, -9.80000e+00,  3.26849e+07],
#        ...,
#        [ 1.01000e+01,  9.90000e+00,  2.94808e+07],
#        [ 1.01000e+01,  1.00000e+01,  2.97791e+07],
#        [ 1.01000e+01,  1.01000e+01,  3.00805e+07]])

# %%
0 -> 200, 0
1 -> 199, 0
...
200 -> 0, 0
201 -> skip
202 -> 200, 1
...

# %%
    formatted_table = np.zeros((201, 201, 3))
    for j in range(0, 201, 1):
        for i in range(200, -1, -1):
            formatted_table[i][j] = table[202 * j + 200 - i]

# %%
formatted_table
# Out:
# array([[[-1.00000e+01, -1.00000e+01,  3.32924e+07],
#         [-9.90000e+00, -1.00000e+01,  3.29492e+07],
#         [-9.80000e+00, -1.00000e+01,  3.26095e+07],
#         ...,
#         [ 9.80000e+00, -1.00000e+01,  2.89186e+07],
#         [ 9.90000e+00, -1.00000e+01,  2.92025e+07],
#         [ 1.00000e+01, -1.00000e+01,  2.94893e+07]],
#
#        [[-1.00000e+01, -9.90000e+00,  3.29870e+07],
#         [-9.90000e+00, -9.90000e+00,  3.26438e+07],
#         [-9.80000e+00, -9.90000e+00,  3.23041e+07],
#         ...,
#         [ 9.80000e+00, -9.90000e+00,  2.86201e+07],
#         [ 9.90000e+00, -9.90000e+00,  2.89041e+07],
#         [ 1.00000e+01, -9.90000e+00,  2.91909e+07]],
#
#        [[-1.00000e+01, -9.80000e+00,  3.26849e+07],
#         [-9.90000e+00, -9.80000e+00,  3.23416e+07],
#         [-9.80000e+00, -9.80000e+00,  3.20018e+07],
#         ...,
#         [ 9.80000e+00, -9.80000e+00,  2.83247e+07],
#         [ 9.90000e+00, -9.80000e+00,  2.86086e+07],
#         [ 1.00000e+01, -9.80000e+00,  2.88956e+07]],
#
#        ...,
#
#        [[-1.00000e+01,  9.80000e+00,  3.26849e+07],
#         [-9.90000e+00,  9.80000e+00,  3.23416e+07],
#         [-9.80000e+00,  9.80000e+00,  3.20018e+07],
#         ...,
#         [ 9.80000e+00,  9.80000e+00,  2.83247e+07],
#         [ 9.90000e+00,  9.80000e+00,  2.86086e+07],
#         [ 1.00000e+01,  9.80000e+00,  2.88956e+07]],
#
#        [[-1.00000e+01,  9.90000e+00,  3.29870e+07],
#         [-9.90000e+00,  9.90000e+00,  3.26438e+07],
#         [-9.80000e+00,  9.90000e+00,  3.23041e+07],
#         ...,
#         [ 9.80000e+00,  9.90000e+00,  2.86201e+07],
#         [ 9.90000e+00,  9.90000e+00,  2.89041e+07],
#         [ 1.00000e+01,  9.90000e+00,  2.91909e+07]],
#
#        [[-1.00000e+01,  1.00000e+01,  3.32924e+07],
#         [-9.90000e+00,  1.00000e+01,  3.29492e+07],
#         [-9.80000e+00,  1.00000e+01,  3.26095e+07],
#         ...,
#         [ 9.80000e+00,  1.00000e+01,  2.89186e+07],
#         [ 9.90000e+00,  1.00000e+01,  2.92025e+07],
#         [ 1.00000e+01,  1.00000e+01,  2.94893e+07]]])

# %%
arr = [[1,2],[3,4]]
seaborn.heatmap(arr, cmap="RdBu_r", square=True, linewidths=0.0)

# %%
[(-10, 10), (10, 10)], [(-10, -10), (10, -10)]
